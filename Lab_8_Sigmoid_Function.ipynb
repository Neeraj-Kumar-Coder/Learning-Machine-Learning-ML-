# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
x = np.linspace(-10, 10, 1000)
y = 1 / (1 + np.exp(-x))

plt.title("Sigmoid Curve")
plt.xlabel("x")
plt.ylabel("y")
plt.plot(x, y, c="b")
plt.show()
